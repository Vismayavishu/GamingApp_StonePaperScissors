# %%
# Stone Paper Secissor gaming app using simple Python code
# K J Vismaya
import random
print("Choose your choice")
print("""1. Play Online
2. Play with Friends""")
choice=int(input("Enter choice:"))
# code for online game:
if choice==1:
    m=0 #initialising player score to be 0
    b=0 #initialising the computerscore to be 0
    d=int(input("How many times you want to play this game:"))
    if d%2==0:
        print("Please enter odd number of play times")
    else:
        for i in range(d):
            print("""if choice is 
                   STONE=1
                   PAPER=2
                   SECISSORS=3""")
            for i in range(1):
                n=int(input("Please choose ua choice:"))
            v=random.randint(1,3) #assigning the random number generated to variable v
            if v==1:
                print("We choose: stone")
            elif v==2:
                print("We choose: paper")
            else:
                print("We choose: secissors")
            if n==1:
                if v==1:
                    print(".....GAME DRAW.....")
                elif v==2:
                    print(".....YOU LOST.....")
                else:
                    s=1
                    print(".....YOU WON......") 
            elif n==2:
                if v==1:
                    p=1
                    print(".....YOU WON......")         
                elif v==2:
                    print(".....GAME DRAW......")
                else:
                    print(".....YOU LOST.....")       
            else:
                if v==1:
                    print(".....YOU LOST.....")
                   
                elif v==2:
                    l=1
                    print(".....YOU WON......")
                   
                else:
                    print(".....GAME DRAW.....")
                    #finding the score
            if (n==1 and v==3) or (n==2 and v==1) or (n==3 and v==2):
                for i in range(1):
                    m=m+1
                    print("Your Score is:", m)
                    print("Computer score is:",b)
            elif (n==1 and v==2) or (n==2 and v==3) or (n==3 and v==1):
                for i in range(1):
                    b=b+1
                    print("Your Score is:", m)
                    print("Computer Score is:", b)
            else:
                print("Game draw so there is no score for either of player")
    #declaring the champion
    if m>b:
        print("You won the game by", m-b, "points")
        print("Congradulations!!!!1")
        print("You are Champion")
    elif m==b:
        print("Game Draw")
    else:
        print("You lost the game by", b-m, "points")
 #code for offline game   
else:
    m=0 #initialising the player 1 score to be 0
    b=0 #initialising the score of player 2 to 0
    d=int(input("Please enter number of time you want to play this game:"))
    if d%2==0:
        print("Please choose odd number of times")
    else:
       for i in range(d):
            
            print("""if choice is 
                   STONE=1
                   PAPER=2
                   SECISSORS=3""")
            for i in range(1):
                n=int(input("Player one choice is:"))
                v= int(input("Player 2 choice is:"))
          
            if n==1:
                if v==1:
                    print(".....GAME DRAW.....")
                elif v==2:
                    print(".....Player 2 won.....")
                else:
                    s=1
                    print(".....Player 1 WON......")
                    
                    
            elif n==2:
                if v==1:
                    p=1
                    print(".....Player 1 WON......")
                            
                elif v==2:
                    print(".....GAME DRAW......")
                else:
                    print(".....Player 2 won.....")
                    
            else:
                if v==1:
                    print(".....Player 2 won.....")
                   
                elif v==2:
                    l=1
                    print(".....Player 1 WON......")
                   
                else:
                    print(".....GAME DRAW.....")
                    #printing the scores
            if (n==1 and v==3) or (n==2 and v==1) or (n==3 and v==2):
                for i in range(1):
                    m=m+1
                    print("Player 1 score is:", m)
            elif (n==1 and v==2) or (n==2 and v==3) or (n==3 and v==1):
                for i in range(1):
                    b=b+1
                    print("Player 2 score is:", b)
            else:
                print("Game draw so there is no score for either of player")
    #finding the champion
    if m>b:
        print("Player 1 won the game by", m-b, "score and is winner")
    else:
        print("Player 2 won the game by", b-m, "score and is winner")
# Out:
# Choose your choice
# 1. Play Online
# 2. Play with Friends
# Enter choice:1
